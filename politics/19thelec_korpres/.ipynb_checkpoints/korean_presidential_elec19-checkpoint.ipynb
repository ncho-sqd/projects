# %% [markdown]
# # 19대 대선 Overview
# 일생일대의 정권교체를 이룬 19대 대선.  데이터를 통해 분석해보자.

# %%
# -- encoding: utf-8 --
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import os

# %matplotlib inline

# set Korean to display on matplotlib
korfont = font_manager.FontProperties(fname="C:\\Windows\\Fonts\\malgun.ttf").get_name()
rc('font', family = korfont)

# %% [markdown]
# ## Data Prep/Diagnostics

# %%
# import raw datafile for 19th presidential election
filename = "C:\\Users\\Neil\\Downloads\\@@20170510-19대선-투표구별개표자료(공개용).xlsx"
filecon = pd.ExcelFile(filename)

#check how many tabs
filecon.sheet_names
pres19 = pd.read_excel(filename, '19대선')

# %%
pres19.head(5)
# Out:
#      시도명 구시군명     읍면동명 투표구명        선거인수         투표수     후보자별 득표수  Unnamed: 7  \
# 0    NaN  NaN      NaN  NaN         NaN         NaN  더불어민주당\n문재인  자유한국당\n홍준표
# 1     전국  NaN      NaN  NaN  42479710.0  32807908.0     13423800     7852849
# 2  서울특별시   합계      NaN  NaN   8382999.0   6590646.0      2781345     1365285
# 3  서울특별시  종로구       합계  NaN    133769.0    102566.0        42512       22325
# 4  서울특별시  종로구  거소·선상투표  NaN       218.0       206.0           64          42
#
#   Unnamed: 8 Unnamed: 9    ...     Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# 0  국민의당\n안철수  바른정당\n유승민    ...      경제애국당\n오영국  국민대통합당\n장성민  늘푸른한국당\n이재오
# 1    6998342    2208771    ...            6040        21709         9140
# 2    1492767     476973    ...             789         3554         1938
# 3      22313       7412    ...               5           78           31
# 4         65          8    ...               1            3            1
#
#   Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19     무효투표수  \
# 0  민중연합당\n김선동  한국국민당\n이경희    홍익당\n윤홍식    무소속\n김민찬           계       NaN
# 1       27229       11355       18543       33990    32672175  135733.0
# 2        3416        1277        2177        3950     6568917   21729.0
# 3          63          26          47          49      102202     364.0
# 4           0           0           0           2         201       5.0
#
#          기권수
# 0        NaN
# 1  9671802.0
# 2  1792353.0
# 3    31203.0
# 4       12.0
#
# [5 rows x 22 columns]

# %%
# check for factor values each variables take and count of null values
for var in pres19.columns.values:
    if 'Unnamed' not in var:
        factor = pres19[var].unique()
        nanct = pd.isnull(factor).sum()
        print('{}({},nan: {}): {}\n'.format(var, len(factor), nanct, factor[:10]))

# print all rows with any columns taking null value       
factor_vars = [var for var in pres19.columns.values if 'Unnamed' not in var]
pres19[pres19[factor_vars].isnull().any(1)]
# Out:
# 시도명(19,nan: 1): [nan '전국' '서울특별시' '부산광역시' '대구광역시' '인천광역시' '광주광역시' '대전광역시' '울산광역시' '세종특별자치시']
#
# 구시군명(229,nan: 1): [nan '합계' '종로구' '중구' '용산구' '성동구' '광진구' '동대문구' '중랑구' '성북구']
#
# 읍면동명(3156,nan: 1): [nan '합계' '거소·선상투표' '관외사전투표' '재외투표' '청운효자동' '사직동' '삼청동' '부암동' '평창동']
#
# 투표구명(13161,nan: 1): [nan '합계' '관내사전투표' '청운효자동제1투' '청운효자동제2투' '청운효자동제3투' '사직동제1투' '사직동제2투'
#  '삼청동투표소' '부암동제1투']
#
# 선거인수(7107,nan: 1): [             nan   4.24797100e+07   8.38299900e+06   1.33769000e+05
#    2.18000000e+02   1.28030000e+04   2.49000000e+03   9.37800000e+03
#    1.78400000e+03   2.49300000e+03]
#
# 투표수(6353,nan: 1): [             nan   3.28079080e+07   6.59064600e+06   1.02566000e+05
#    2.06000000e+02   1.28030000e+04   1.81300000e+03   7.29500000e+03
#    1.78400000e+03   1.68200000e+03]
#
# 후보자별 득표수(4221,nan: 0): ['더불어민주당\n문재인' 13423800 2781345 42512 64 5842 987 3109 819 664]
#
# 무효투표수(391,nan: 1): [             nan   1.35733000e+05   2.17290000e+04   3.64000000e+02
#    5.00000000e+00   6.70000000e+01   8.00000000e+00   2.20000000e+01
#    3.00000000e+00   1.00000000e+01]
#
# 기권수(3656,nan: 1): [             nan   9.67180200e+06   1.79235300e+06   3.12030000e+04
#    1.20000000e+01   0.00000000e+00   6.77000000e+02   2.08300000e+03
#    8.11000000e+02   6.58000000e+02]
#            시도명  구시군명           읍면동명 투표구명        선거인수         투표수     후보자별 득표수  \
# 0          NaN   NaN            NaN  NaN         NaN         NaN  더불어민주당\n문재인
# 1           전국   NaN            NaN  NaN  42479710.0  32807908.0     13423800
# 2        서울특별시    합계            NaN  NaN   8382999.0   6590646.0      2781345
# 3        서울특별시   종로구             합계  NaN    133769.0    102566.0        42512
# 4        서울특별시   종로구        거소·선상투표  NaN       218.0       206.0           64
# 5        서울특별시   종로구         관외사전투표  NaN     12803.0     12803.0         5842
# 6        서울특별시   종로구           재외투표  NaN      2490.0      1813.0          987
# 84       서울특별시   종로구  잘못 투입·구분된 투표지  NaN         0.0         0.0            0
# 85       서울특별시    중구             합계  NaN    109836.0     82852.0        34062
# 86       서울특별시    중구        거소·선상투표  NaN       174.0       157.0           60
# 87       서울특별시    중구         관외사전투표  NaN     10177.0     10173.0         4848
# 88       서울특별시    중구           재외투표  NaN      1715.0      1156.0          633
# 163      서울특별시    중구  잘못 투입·구분된 투표지  NaN         0.0         0.0            0
# 164      서울특별시   용산구             합계  NaN    197962.0    148157.0        58081
# 165      서울특별시   용산구        거소·선상투표  NaN       244.0       231.0           88
# 166      서울특별시   용산구         관외사전투표  NaN     18318.0     18288.0         8077
# 167      서울특별시   용산구           재외투표  NaN      3497.0      2547.0         1277
# 259      서울특별시   용산구  잘못 투입·구분된 투표지  NaN         0.0         0.0            0
# 260      서울특별시   성동구             합계  NaN    259009.0    203175.0        86686
# 261      서울특별시   성동구        거소·선상투표  NaN       358.0       342.0          125
# 262      서울특별시   성동구         관외사전투표  NaN     23632.0     23616.0        11080
# 263      서울특별시   성동구           재외투표  NaN      3007.0      2309.0         1314
# 367      서울특별시   성동구  잘못 투입·구분된 투표지  NaN         0.0         2.0            1
# 368      서울특별시   광진구             합계  NaN    305172.0    240030.0       105512
# 369      서울특별시   광진구        거소·선상투표  NaN       384.0       370.0          145
# 370      서울특별시   광진구         관외사전투표  NaN     27805.0     27803.0        13607
# 371      서울특별시   광진구           재외투표  NaN      3250.0      2494.0         1472
# 486      서울특별시   광진구  잘못 투입·구분된 투표지  NaN         0.0         0.0            0
# 487      서울특별시  동대문구             합계  NaN    304972.0    236092.0        98958
# 488      서울특별시  동대문구        거소·선상투표  NaN       399.0       376.0          117
# ...        ...   ...            ...  ...         ...         ...          ...
# 21687     경상남도   함양군        거소·선상투표  NaN       262.0       242.0           80
# 21688     경상남도   함양군         관외사전투표  NaN      2747.0      2747.0         1090
# 21689     경상남도   함양군           재외투표  NaN       299.0       152.0           73
# 21730     경상남도   함양군  잘못 투입·구분된 투표지  NaN         0.0         0.0            0
# 21731     경상남도   산청군             합계  NaN     32215.0     24513.0         6561
# 21732     경상남도   산청군        거소·선상투표  NaN       155.0       134.0           42
# 21733     경상남도   산청군         관외사전투표  NaN      3440.0      3440.0         1338
# 21734     경상남도   산청군           재외투표  NaN       292.0       131.0           64
# 21773     경상남도   산청군  잘못 투입·구분된 투표지  NaN         0.0         0.0            0
# 21774     경상남도   거창군             합계  NaN     53345.0     41325.0        11256
# 21775     경상남도   거창군        거소·선상투표  NaN       153.0       139.0           34
# 21776     경상남도   거창군         관외사전투표  NaN      3978.0      3978.0         1592
# 21777     경상남도   거창군           재외투표  NaN       513.0       258.0          148
# 21823     경상남도   거창군  잘못 투입·구분된 투표지  NaN         0.0         0.0            0
# 21824     경상남도   합천군             합계  NaN     42887.0     33021.0         7143
# 21825     경상남도   합천군        거소·선상투표  NaN       321.0       304.0           51
# 21826     경상남도   합천군         관외사전투표  NaN      4100.0      4100.0         1392
# 21827     경상남도   합천군           재외투표  NaN       548.0       223.0           96
# 21887     경상남도   합천군  잘못 투입·구분된 투표지  NaN         0.0         0.0            0
# 21888  제주특별자치도    합계            NaN  NaN    518000.0    374459.0       169493
# 21889  제주특별자치도   제주시             합계  NaN    375292.0    273163.0       125717
# 21890  제주특별자치도   제주시        거소·선상투표  NaN      1182.0      1116.0          474
# 21891  제주특별자치도   제주시         관외사전투표  NaN     22492.0     22491.0        10799
# 21892  제주특별자치도   제주시           재외투표  NaN      4418.0      2259.0         1178
# 22087  제주특별자치도   제주시  잘못 투입·구분된 투표지  NaN         0.0         0.0            0
# 22088  제주특별자치도  서귀포시             합계  NaN    142708.0    101296.0        43776
# 22089  제주특별자치도  서귀포시        거소·선상투표  NaN       588.0       562.0          195
# 22090  제주특별자치도  서귀포시         관외사전투표  NaN     12687.0     12687.0         6111
# 22091  제주특별자치도  서귀포시           재외투표  NaN      1610.0       834.0          439
# 22214  제주특별자치도  서귀포시  잘못 투입·구분된 투표지  NaN         0.0         0.0            0
#
#        Unnamed: 7 Unnamed: 8 Unnamed: 9    ...     Unnamed: 12  Unnamed: 13  \
# 0      자유한국당\n홍준표  국민의당\n안철수  바른정당\n유승민    ...      경제애국당\n오영국  국민대통합당\n장성민
# 1         7852849    6998342    2208771    ...            6040        21709
# 2         1365285    1492767     476973    ...             789         3554
# 3           22325      22313       7412    ...               5           78
# 4              42         65          8    ...               1            3
# 5            2025       2509       1156    ...               0            4
# 6             215        304         75    ...               0            1
# 84              0          0          0    ...               0            0
# 85          17901      19372       5874    ...              12           53
# 86             34         48          8    ...               0            0
# 87           1596       2093        809    ...               2            1
# 88            164        189         35    ...               0            0
# 163             0          0          0    ...               0            0
# 164         35230      32109      11825    ...              17           68
# 165            51         66         16    ...               0            1
# 166          3320       3690       1531    ...               3            5
# 167           351        443        144    ...               0            1
# 259             0          0          0    ...               0            0
# 260         40566      45674      15859    ...              16           94
# 261            54        115         24    ...               1            0
# 262          3532       4912       2033    ...               3            9
# 263           183        378        111    ...               0            1
# 367             0          1          0    ...               0            0
# 368         46368      52824      17114    ...              24          120
# 369            53        123         28    ...               1            0
# 370          3918       5565       2084    ...               6            9
# 371           208        398        107    ...               0            1
# 486             0          0          0    ...               0            0
# 487         51631      53359      15129    ...              41          150
# 488            76        135         23    ...               1            0
# ...           ...        ...        ...    ...             ...          ...
# 21687          67         28         11    ...               3            1
# 21688         754        368        211    ...               0            1
# 21689          19         41          5    ...               0            0
# 21730           0          0          0    ...               0            0
# 21731       12544       2753       1196    ...               6           21
# 21732          45         29          7    ...               0            1
# 21733        1110        420        279    ...               2            6
# 21734           8         40          9    ...               0            0
# 21773           0          0          0    ...               0            0
# 21774       19976       4923       2447    ...              12           37
# 21775          61         26          8    ...               0            0
# 21776         919        616        397    ...               0            8
# 21777          17         62          3    ...               0            0
# 21823           0          0          0    ...               0            0
# 21824       19699       3077       1317    ...              23           26
# 21825         150         42         12    ...               3            3
# 21826        1482        505        372    ...               2            3
# 21827          22         78          9    ...               1            0
# 21887           0          0          0    ...               0            0
# 21888       68063      77861      22784    ...             269          312
# 21889       48027      55971      16885    ...              96          193
# 21890         152        277         65    ...               5            5
# 21891        2512       4218       2146    ...               7           15
# 21892         130        628         62    ...               0            0
# 22087           0          0          0    ...               0            0
# 22088       20036      21890       5899    ...             173          119
# 22089          88        145         57    ...               2            0
# 22090        1658       2276       1048    ...               5            7
# 22091          52        210         27    ...               0            0
# 22214           0          0          0    ...               0            0
#
#        Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18  \
# 0      늘푸른한국당\n이재오  민중연합당\n김선동  한국국민당\n이경희    홍익당\n윤홍식    무소속\n김민찬
# 1             9140       27229       11355       18543       33990
# 2             1938        3416        1277        2177        3950
# 3               31          63          26          47          49
# 4                1           0           0           0           2
# 5                2          15           6           9           6
# 6                0           1           0           0           0
# 84               0           0           0           0           0
# 85              21          55          18          25          51
# 86               0           0           0           0           1
# 87               0           9           3           4           7
# 88               1           2           0           0           0
# 163              0           0           0           0           0
# 164             23          72          32          51          80
# 165              0           0           0           0           0
# 166              3          20           4           7          19
# 167              0           1           1           1           1
# 259              0           0           0           0           0
# 260             46         108          41          58         124
# 261              0           1           1           1           0
# 262              5          12          10           5          22
# 263              1           1           1           2           2
# 367              0           0           0           0           0
# 368             48         127          48          65         129
# 369              1           0           2           1           0
# 370              6          17           7           8          29
# 371              0           4           0           1           0
# 486              0           0           0           0           0
# 487             44         160          80          84         162
# 488              0           0           1           0           0
# ...            ...         ...         ...         ...         ...
# 21687            4           5           1           2           3
# 21688            0           0           2           3           5
# 21689            0           0           0           0           0
# 21730            0           0           0           0           0
# 21731           19          21          34          91          73
# 21732            1           0           0           0           1
# 21733            0           3           3           3           8
# 21734            0           0           0           0           0
# 21773            0           0           0           0           0
# 21774           22          48          54         105         100
# 21775            1           0           0           0           0
# 21776            3           3           5           8          17
# 21777            0           1           0           0           0
# 21823            0           0           0           0           0
# 21824           16          28          51         153          76
# 21825            0           0           1           2           3
# 21826            2           3           0           2           4
# 21827            0           0           0           0           2
# 21887            0           0           0           0           0
# 21888          113         335         236         289         556
# 21889           73         257         153         178         368
# 21890            3           5           8           6           6
# 21891            3          19          11           8          52
# 21892            0           3           1           0           0
# 22087            0           0           0           0           0
# 22088           40          78          83         111         188
# 22089            1           1           8           1           2
# 22090            5          10           3           3          30
# 22091            0           0           0           1           1
# 22214            0           0           0           0           0
#
#       Unnamed: 19     무효투표수        기권수
# 0               계       NaN        NaN
# 1        32672175  135733.0  9671802.0
# 2         6568917   21729.0  1792353.0
# 3          102202     364.0    31203.0
# 4             201       5.0       12.0
# 5           12736      67.0        0.0
# 6            1805       8.0      677.0
# 84              0       0.0        0.0
# 85          82595     257.0    26984.0
# 86            154       3.0       17.0
# 87          10142      31.0        4.0
# 88           1155       1.0      559.0
# 163             0       0.0        0.0
# 164        147660     497.0    49805.0
# 165           229       2.0       13.0
# 166         18207      81.0       30.0
# 167          2532      15.0      950.0
# 259             0       0.0        0.0
# 260        202512     663.0    55834.0
# 261           334       8.0       16.0
# 262         23515     101.0       16.0
# 263          2300       9.0      698.0
# 367             2       0.0       -2.0
# 368        239231     799.0    65142.0
# 369           364       6.0       14.0
# 370         27662     141.0        2.0
# 371          2488       6.0      756.0
# 486             0       0.0        0.0
# 487        235265     827.0    68880.0
# 488           366      10.0       23.0
# ...           ...       ...        ...
# 21687         219      23.0       20.0
# 21688        2712      35.0        0.0
# 21689         150       2.0      147.0
# 21730           0       0.0        0.0
# 21731       24295     218.0     7702.0
# 21732         129       5.0       21.0
# 21733        3416      24.0        0.0
# 21734         131       0.0      161.0
# 21773           0       0.0        0.0
# 21774       40949     376.0    12020.0
# 21775         135       4.0       14.0
# 21776        3942      36.0        0.0
# 21777         257       1.0      255.0
# 21823           0       0.0        0.0
# 21824       32711     310.0     9866.0
# 21825         273      31.0       17.0
# 21826        4075      25.0        0.0
# 21827         221       2.0      325.0
# 21887           0       0.0        0.0
# 21888      372412    2047.0   143541.0
# 21889      271780    1383.0   102129.0
# 21890        1064      52.0       66.0
# 21891       22306     185.0        1.0
# 21892        2253       6.0     2159.0
# 22087           0       0.0        0.0
# 22088      100632     664.0    41412.0
# 22089         523      39.0       26.0
# 22090       12602      85.0        0.0
# 22091         828       6.0      776.0
# 22214           0       0.0        0.0
#
# [1269 rows x 22 columns]

# %%
# define new variable column and identify key vars to melt further down
newvars = np.where(['Unnamed' in var or var == '후보자별 득표수' for var in pres19.columns.values], pres19.iloc[0], pres19.columns.values)
keyvars = [var1 for var1, var2 in zip(pres19.columns.values, pres19.iloc[0]) if 'Unnamed' not in var1 and var1 != '후보자별 득표수']

pres19.columns = newvars
pres19 = pres19.iloc[1:,:]

# %%
# melt data to long form
long = pres19.melt(keyvars, var_name = '후보자', value_name = '득표수')

# check if melting is correctly done
(long.loc[((long.시도명 == '전국') & (long.후보자 != '계')), '득표수'].sum() 
 == long.loc[(long.후보자 == '계') & (long.시도명 == '전국'), '득표수'])
# Out:
# 288782    True
# Name: 득표수, dtype: bool

# %% [markdown]
# ## High-level summary

# %%
total = (long.loc[((long.시도명 == '전국') & (long.후보자 != '계')), ['후보자', '득표수']]
             .sort_values('득표수', ascending = False)
             .reset_index())

total['%'] = total.득표수  / total.득표수.sum()
ax = total.plot.bar('후보자','득표수',figsize = (15,7), title = '19대 대선 후보자별 총 득표수', rot=0)
#_ = ax.set_xticklabels(total.후보자, rotation = 0)

# annotate percentage count
for i, p in enumerate(ax.patches):
    perc = "{}%".format(round(total.loc[i, '%'] * 100, 2))
    ax.annotate(perc, (p.get_x() * 1.005, p.get_height() * 1.005))

# %% [markdown]
# ## 선거인수 = 투표수 + 기권수?  투표수는 무효투표수 포함?
# 선관위에서 기록하는 선거 집계수에는 4가지 종류가 있다: <br/>
# * 선거인수
# * 투표수
# * 무효투표수
# * 기권수<br/>
#
# 선거인수라 하면 선거장에 들어간 총 머릿수 (headcount)로 이해할 수 있을 듯 하다.  어떤 이유에서건 선거장에 소중한 한 표를 행사하러 오긴 했으니 "참정권 행사 의지를 투표 참여행위로 드러낸 인원 수" 정도로 정의 될 수 있겠다.  기록 상으로도 선거인수는 투표수와 기권수의 합으로 확인 되고 투표수가 무효투표수를 포함하는 것으로 나타나니 (득표수 = 투표수 - 무효투표수) 선거인수는 특정 선거 지역의 참정권의지를 나타내는 지표가 될 수 있을 듯하다.  물론 총 투표가능 연령 인구를 base로 normalization이 필요하지만 말이다.  이를 바탕으로 경기도와 서울특별시가 압도적으로 높은 선거인수를 가지고 있는 것을 볼 수 있다.

# %%
filt = long.후보자 == '계'
print((long.선거인수 != (long.투표수 + long.기권수)).sum())    # 선거인수 = 투표수 + 기권수? expecting == 0
print((long[filt].득표수 != (long[filt].투표수 - long[filt].무효투표수)).sum())    # 득표수 = 투표수 - 무효투표수? expecting == 0

summ = long[(long.구시군명 == '합계') & filt].sort_values('선거인수', ascending = False)
summ
# Out:
# 0
# 0
#             시도명 구시군명 읍면동명 투표구명        선거인수        투표수    무효투표수        기권수 후보자  \
# 297014      경기도   합계  NaN  NaN  10262309.0  7916009.0  28364.0  2346300.0   계
# 288783    서울특별시   합계  NaN  NaN   8382999.0  6590646.0  21729.0  1792353.0   계
# 292006    부산광역시   합계  NaN  NaN   2950224.0  2261633.0   8924.0   688591.0   계
# 309031     경상남도   합계  NaN  NaN   2744633.0  2135055.0  12416.0   609578.0   계
# 294339    인천광역시   합계  NaN  NaN   2409031.0  1820091.0   7128.0   588940.0   계
# 307289     경상북도   합계  NaN  NaN   2249984.0  1711627.0  10401.0   538357.0   계
# 293403    대구광역시   합계  NaN  NaN   2043276.0  1581347.0   6971.0   461929.0   계
# 303313     충청남도   합계  NaN  NaN   1711912.0  1240204.0   6258.0   471708.0   계
# 305711     전라남도   합계  NaN  NaN   1572838.0  1238738.0   6326.0   334100.0   계
# 304538     전라북도   합계  NaN  NaN   1525626.0  1205794.0   4791.0   319832.0   계
# 302453     충청북도   합계  NaN  NaN   1303688.0   975441.0   4882.0   328247.0   계
# 301326      강원도   합계  NaN  NaN   1287173.0   955885.0   5249.0   331288.0   계
# 295959    대전광역시   합계  NaN  NaN   1220602.0   945897.0   3596.0   274705.0   계
# 295380    광주광역시   합계  NaN  NaN   1166901.0   957321.0   2489.0   209580.0   계
# 296499    울산광역시   합계  NaN  NaN    941093.0   744960.0   3598.0   196133.0   계
# 310669  제주특별자치도   합계  NaN  NaN    518000.0   374459.0   2047.0   143541.0   계
# 296913  세종특별자치시   합계  NaN  NaN    189421.0   152801.0    564.0    36620.0   계
#
#             득표수
# 297014  7887645
# 288783  6568917
# 292006  2252709
# 309031  2122639
# 294339  1812963
# 307289  1701226
# 293403  1574376
# 303313  1233946
# 305711  1232412
# 304538  1201003
# 302453   970559
# 301326   950636
# 295959   942301
# 295380   954832
# 296499   741362
# 310669   372412
# 296913   152237

# %%
summ.plot.bar('시도명', '선거인수', figsize = (15, 7), rot = 30)

# %% [markdown]
# 위에서 언급 하였듯 투표수는 (총)득표수와 무효투표수의 합으로 확인된다.  어떤 이유에서 무효투표 처리 됐든 이는 "투표 의사를 분명히 표현하지 못한 자" 또는 지역구 선관위 개표결과의 엄함 정도를 나타내는 지표가 이해할 수 있을 듯하다.  (총)득표수는 이에 반하는 의미로서 "투표 의사를 분명히 표현한 자"로 해석 될 수 있다.  기권수는 "투표 의사는 있지만 passive한 선택을 한 인원 수로 볼 수 있을 듯 하다.
#
# 따라서 밑의 3가지 지표의 breakdown은 각 선거구 선거인수의 "성격"을 보여주는 좋은 지표가 될 수 있다
#
# * 득표수
# * 무효투표수
# * 기권수

# %%
stacked = summ[['시도명', '득표수', '무효투표수', '기권수']].set_index('시도명')
stacked = stacked.div(stacked.sum(1), axis = 0)
stacked.plot.bar(figsize = (15, 7), stacked=True, rot = 60)

# %% [markdown]
# 시도명 별로 크게 눈에 뛰는 패턴이 드러나보이지는 않는듯하다.  그러나 실제 수치로 들어가 보면 시도명 별 전체 선거인수의 %수치로 무효투표수는 2배 이상 그리고 기권수는 1.5배 이상 차이가 나는 것으로 드러난다. 이는 시도명 별로 꽤나 interesting한 pattern을 보인다.  무표투표수는 워낙에 작은 수치이기에 선거의 당락을 결정짓는 요소로 이해하기 보단 그 지역구 선거인수의 성격을 보여주는 수치로서 더 유용할 듯하나, 기권수는 각 시도 선거인수의 20% 이상을 상회하게 때문에, close race에서는 선거의 결과를 좌우하는 하나의 중요한 요인이 될 수 있다.

# %%
(stacked.max() / stacked.min()).sort_values(ascending = False)
# Out:
# 무효투표수    2.167229
# 기권수      1.542874
# 득표수      1.138149
# dtype: float64

# %%
stacked.sort_values('무효투표수', ascending = False).plot.bar(y = '무효투표수', figsize = (15,10), subplots=True, layout=(2,1))
stacked.sort_values('기권수', ascending = False).plot.bar(y = '기권수', figsize = (15,10), subplots = True, layout = (2,1))
# try clustering these charts into 3 groups.
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8AD1E8CC0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8AD137E80>]], dtype=object)
